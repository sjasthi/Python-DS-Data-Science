# %% [markdown]
# # 📊 Assignment: Pandas — Reading, Exploring, Transforming & Writing Data
#
# ## Python for Data Science
# ### Instructor: Siva Jasthi, Ph.D.
# ### Learn and Help | www.learnandhelp.com
#
# ---
#
# | | |
# |---|---|
# | **Total Points** | 25 |
# | **Student Name** | ✏️ *Type your name here* |
# | **Date Submitted** | ✏️ *Type the date here* |
#
# ---

# %% [markdown]
# ## 🎯 Objective
#
# In this assignment, you will:
# 1. **Read** a real-world dataset from Kaggle using Pandas
# 2. **Explore** the data using EDA (Exploratory Data Analysis) techniques
# 3. **Create** two new columns by recoding existing data
# 4. **Write** the transformed data to both CSV and Excel formats
#
# ---

# %% [markdown]
# ## 📁 Dataset Information
#
# **Dataset Name:** Students Performance in Exams
#
# **Kaggle Link:** https://www.kaggle.com/datasets/spscientist/students-performance-in-exams
#
# This dataset contains **1,000 records** of student exam scores with **8 columns**:
#
# | Column Name | Description |
# |---|---|
# | `gender` | Male or Female |
# | `race/ethnicity` | Group A through Group E |
# | `parental level of education` | Ranges from some high school to master's degree |
# | `lunch` | Standard or free/reduced |
# | `test preparation course` | Completed or none |
# | `math score` | Numeric score (0–100) |
# | `reading score` | Numeric score (0–100) |
# | `writing score` | Numeric score (0–100) |
#
# ### 📥 How to get the dataset:
# 1. Go to the Kaggle link above and click **"Download"** (you may need a free Kaggle account)
# 2. Unzip the downloaded file — you will find `StudentsPerformance.csv`
# 3. Upload this CSV file to Google Colab using the file upload method shown in class
#
# ---

# %% [markdown]
# ## ✅ Task 1: Read the Dataset into a Pandas DataFrame (3 Points)
#
# | Sub-task | Points |
# |---|---|
# | a) Import the pandas library | 1 |
# | b) Use `pd.read_csv()` to load the CSV into a DataFrame named `df` | 1 |
# | c) Display the first 5 rows using `df.head()` | 1 |

# %% [markdown]
# ### 1a) Import the pandas library

# %%
# TODO: Import the pandas library
# Hint: import pandas as pd

# %% [markdown]
# ### 1b) Read the CSV file into a DataFrame
#
# > 💡 **Hint:** If you uploaded the file to Colab, use: `df = pd.read_csv('StudentsPerformance.csv')`

# %%
# TODO: Read the CSV file into a DataFrame named 'df'

# %% [markdown]
# ### 1c) Display the first 5 rows to verify the data loaded correctly

# %%
# TODO: Display the first 5 rows of the DataFrame
# Hint: df.head()

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Task 2: Exploratory Data Analysis — EDA (10 Points)
#
# This task has **two parts**:
# - **Part A (5 pts):** Run 5 EDA commands and add a comment explaining what each output tells you
# - **Part B (5 pts):** Answer 5 questions using Pandas functions

# %% [markdown]
# ### Part A: Run EDA Commands (5 Points — 1 point each)
#
# For each command below, **run the code** and **add a comment** explaining what the output tells you.

# %% [markdown]
# #### 2a) `df.shape` — How many rows and columns does the dataset have? (1 pt)

# %%
# TODO: Check the shape of the DataFrame
# After running, add a comment below explaining: How many rows? How many columns?


# Answer:

# %% [markdown]
# #### 2b) `df.info()` — What are the data types? Are there missing values? (1 pt)

# %%
# TODO: Display the info of the DataFrame
# After running, add a comment: What data types do you see? Are there any missing values (null counts)?


# Answer:

# %% [markdown]
# #### 2c) `df.describe()` — What are the statistics for numeric columns? (1 pt)

# %%
# TODO: Display the statistical summary of the DataFrame
# After running, add a comment: What is the mean math score? What are the min and max values?


# Answer:

# %% [markdown]
# #### 2d) `df['gender'].value_counts()` — How many male vs female students? (1 pt)

# %%
# TODO: Count the number of male and female students


# Answer:

# %% [markdown]
# #### 2e) `df['test preparation course'].value_counts()` — Test prep completion counts? (1 pt)

# %%
# TODO: Count how many students completed vs did not complete the test prep course


# Answer:

# %% [markdown]
# ---

# %% [markdown]
# ### Part B: Answer These 5 Questions Using Pandas (5 Points — 1 point each)
#
# > 💡 **Helpful functions:** `df.groupby()`, `df['column'].mean()`, `df['column'].max()`, `df['column'].min()`, `df['column'].value_counts()`

# %% [markdown]
# #### Q1: What is the average math score for all students? (1 pt)

# %%
# TODO: Calculate the average (mean) math score
# Hint: df['math score'].mean()


# Answer: The average math score is ______

# %% [markdown]
# #### Q2: Which gender has a higher average reading score? (1 pt)

# %%
# TODO: Find the average reading score for each gender
# Hint: df.groupby('gender')['reading score'].mean()


# Answer: ______ has a higher average reading score of ______

# %% [markdown]
# #### Q3: What is the most common parental level of education in the dataset? (1 pt)

# %%
# TODO: Find the most common parental level of education
# Hint: df['parental level of education'].value_counts()


# Answer: The most common parental level of education is ______

# %% [markdown]
# #### Q4: Do students who completed the test prep course have higher average writing scores? (1 pt)
#
# > 💡 **Hint:** Use `groupby` on the `test preparation course` column

# %%
# TODO: Compare average writing scores between students who completed vs did not complete test prep
# Hint: df.groupby('test preparation course')['writing score'].mean()


# Answer: Students who completed the test prep course have an average writing score of ______
#         Students who did NOT complete it have an average writing score of ______
#         So, (completed / not completed) ______ has a higher average writing score.

# %% [markdown]
# #### Q5: What is the highest and lowest math score in the dataset? (1 pt)

# %%
# TODO: Find the highest (max) and lowest (min) math score
# Hint: df['math score'].max() and df['math score'].min()


# Answer: Highest math score = ______, Lowest math score = ______

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Task 3: Recode Two Columns to Create Two New Columns (7 Points)
#
# You will create **two brand-new columns** in the DataFrame by transforming existing data.

# %% [markdown]
# ### New Column 1: `average_score` (3 Points)
#
# Create a new column called `average_score` that calculates the **average of the three exam scores** for each student.
#
# **Formula:**
# ```
# average_score = (math score + reading score + writing score) / 3
# ```
#
# > 💡 **Remember:** Round the result to 2 decimal places using `.round(2)`

# %%
# TODO: Create the 'average_score' column
# Step 1: Calculate the average of the three score columns
# Step 2: Round to 2 decimal places
#
# Hint: df['average_score'] = ((df['math score'] + df['reading score'] + df['writing score']) / 3).round(2)


# Display the first few rows to verify

# %% [markdown]
# ### New Column 2: `performance_grade` (4 Points)
#
# Using the `average_score` column you just created, recode it into a **letter grade** using this grading scale:
#
# | Average Score Range | Grade | Meaning |
# |:---:|:---:|:---:|
# | 90 and above | **A** | Excellent |
# | 80 – 89 | **B** | Good |
# | 70 – 79 | **C** | Average |
# | 60 – 69 | **D** | Below Average |
# | Below 60 | **F** | Failing |
#
# > 💡 **Hint:** You can use a custom function with `df.apply()`, or use `pd.cut()`, or use `np.select()`
#
# Below is **one approach** using a custom function — feel free to use any method you like!

# %%
# TODO: Create the 'performance_grade' column
#
# APPROACH 1: Using a custom function with apply()
# ------------------------------------------------
# def assign_grade(score):
#     if score >= 90:
#         return 'A'
#     elif score >= 80:
#         return 'B'
#     elif score >= 70:
#         return 'C'
#     elif score >= 60:
#         return 'D'
#     else:
#         return 'F'
#
# df['performance_grade'] = df['average_score'].apply(assign_grade)
#
# ------------------------------------------------
# Write your code below:

# %% [markdown]
# ### Verify: Display the first 10 rows with the new columns

# %%
# TODO: Display the first 10 rows to verify both new columns look correct
# Hint: df.head(10)

# %% [markdown]
# ### Quick Check: Count students in each grade category

# %%
# TODO: Display the count of students in each performance grade
# Hint: df['performance_grade'].value_counts()

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Task 4: Write the Data to CSV and Excel (5 Points)
#
# | Sub-task | Points |
# |---|---|
# | a) Export to CSV | 2 |
# | b) Export to Excel | 2 |
# | c) Read back the CSV to verify | 1 |

# %% [markdown]
# ### 4a) Export to CSV (2 pts)
#
# > 💡 **Important:** Use `index=False` so the row numbers are not saved as a column in the file

# %%
# TODO: Export the DataFrame to a CSV file named 'students_updated.csv'
# Hint: df.to_csv('students_updated.csv', index=False)


print("CSV file saved successfully!")

# %% [markdown]
# ### 4b) Export to Excel (2 pts)
#
# > 💡 **Note:** You may need to install openpyxl first: `!pip install openpyxl`

# %%
# Uncomment the line below if you get an error about openpyxl
# !pip install openpyxl

# TODO: Export the DataFrame to an Excel file named 'students_updated.xlsx'
# Hint: df.to_excel('students_updated.xlsx', index=False)


print("Excel file saved successfully!")

# %% [markdown]
# ### 4c) Read the CSV back in to verify (1 pt)
#
# Read the CSV file you just saved back into a **new** DataFrame and display the first 5 rows to confirm everything exported correctly.

# %%
# TODO: Read the CSV file back into a new DataFrame to verify
# Hint: df_verify = pd.read_csv('students_updated.csv')
#        df_verify.head()

# %% [markdown]
# ---

# %% [markdown]
# ## 📋 Grading Summary
#
# | Task | Points |
# |---|:---:|
# | Task 1: Read the dataset into a Pandas DataFrame | 3 |
# | Task 2a–e: Run EDA commands with comments | 5 |
# | Task 2 Q1–Q5: Answer 5 questions using Pandas | 5 |
# | Task 3: Create `average_score` column | 3 |
# | Task 3: Create `performance_grade` column | 4 |
# | Task 4: Export to CSV and Excel + verify | 5 |
# | **TOTAL** | **25** |
#
# ---

# %% [markdown]
# ---
#
# ## 📤 Submission Checklist
#
# Before you submit, make sure:
#
# - [ ] All code cells have been **run** and output is **visible**
# - [ ] All 5 EDA answers are filled in (Q1–Q5)
# - [ ] Both new columns (`average_score` and `performance_grade`) are created
# - [ ] Both files (`students_updated.csv` and `students_updated.xlsx`) are exported
# - [ ] CSV verification shows the new columns
#
# **Submit to Google Classroom:**
# 1. This notebook (.ipynb file)
# 2. `students_updated.csv`
# 3. `students_updated.xlsx`
#
# ---
#
# ### 🐍📊 Happy Coding!
# © Learn and Help | www.learnandhelp.com
